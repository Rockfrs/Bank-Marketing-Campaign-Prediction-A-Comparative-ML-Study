# %% [markdown]
# ## 1: Logistic Regression

# %%
import pandas as pd
import pickle
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, matthews_corrcoef

# Load data
X_train = pd.read_csv('X_train.csv')
X_test = pd.read_csv('X_test.csv')
y_train = pd.read_csv('y_train.csv').values.ravel()
y_test = pd.read_csv('y_test.csv').values.ravel()

# 1. Initialize and Train
lr_model = LogisticRegression(max_iter=1000, random_state=42)
lr_model.fit(X_train, y_train)

# 2. Predict
y_pred = lr_model.predict(X_test)
y_proba = lr_model.predict_proba(X_test)[:, 1]

# 3. Calculate Metrics
lr_metrics = {
    "Model": "Logistic_Regression",
    "Accuracy": accuracy_score(y_test, y_pred),
    "AUC": roc_auc_score(y_test, y_proba),
    "Precision": precision_score(y_test, y_pred),
    "Recall": recall_score(y_test, y_pred),
    "F1_Score": f1_score(y_test, y_pred),
    "MCC": matthews_corrcoef(y_test, y_pred)
}

# 4. Save Model and Metrics
with open('Logistic_Regression.pkl', 'wb') as f:
    pickle.dump(lr_model, f)

# Store results in a temporary list for the final table
all_results = [lr_metrics]
print("--- Segment 1: Logistic Regression Complete ---")
print(pd.DataFrame([lr_metrics]))
# Out:
# --- Segment 1: Logistic Regression Complete ---
#                  Model  Accuracy       AUC  Precision    Recall  F1_Score  \
# 0  Logistic_Regression  0.893923  0.864363   0.529412  0.183673  0.272727
#
#         MCC
# 0  0.267756

# %% [markdown]
# # 2: Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# 1. Initialize and Train
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)

# 2. Predict
y_pred = dt_model.predict(X_test)
y_proba = dt_model.predict_proba(X_test)[:, 1]

# 3. Calculate Metrics
dt_metrics = {
    "Model": "Decision_Tree",
    "Accuracy": accuracy_score(y_test, y_pred),
    "AUC": roc_auc_score(y_test, y_proba),
    "Precision": precision_score(y_test, y_pred),
    "Recall": recall_score(y_test, y_pred),
    "F1_Score": f1_score(y_test, y_pred),
    "MCC": matthews_corrcoef(y_test, y_pred)
}

# 4. Save
with open('Decision_Tree.pkl', 'wb') as f:
    pickle.dump(dt_model, f)

all_results.append(dt_metrics)
print("--- Segment 2: Decision Tree Complete ---")
print(pd.DataFrame([dt_metrics]))
# Out:
# --- Segment 2: Decision Tree Complete ---
#            Model  Accuracy      AUC  Precision    Recall  F1_Score       MCC
# 0  Decision_Tree  0.872928  0.69566   0.422018  0.469388  0.444444  0.373605

# %% [markdown]
# # 3: K-Nearest Neighbors (kNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

# 1. Initialize and Train
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)

# 2. Predict
y_pred = knn_model.predict(X_test)
y_proba = knn_model.predict_proba(X_test)[:, 1]

# 3. Calculate Metrics
knn_metrics = {
    "Model": "kNN",
    "Accuracy": accuracy_score(y_test, y_pred),
    "AUC": roc_auc_score(y_test, y_proba),
    "Precision": precision_score(y_test, y_pred),
    "Recall": recall_score(y_test, y_pred),
    "F1_Score": f1_score(y_test, y_pred),
    "MCC": matthews_corrcoef(y_test, y_pred)
}

# 4. Save
with open('kNN.pkl', 'wb') as f:
    pickle.dump(knn_model, f)

all_results.append(knn_metrics)
print("--- Segment 3: kNN Complete ---")
print(pd.DataFrame([knn_metrics]))
# Out:
# --- Segment 3: kNN Complete ---
#   Model  Accuracy       AUC  Precision    Recall  F1_Score       MCC
# 0   kNN  0.890608  0.745151   0.486486  0.183673  0.266667  0.251281

# %% [markdown]
# # 4: Naive Bayes (Gaussian)

# %%
from sklearn.naive_bayes import GaussianNB

# 1. Initialize and Train
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)

# 2. Predict
y_pred = nb_model.predict(X_test)
y_proba = nb_model.predict_proba(X_test)[:, 1]

# 3. Calculate Metrics
nb_metrics = {
    "Model": "Naive_Bayes",
    "Accuracy": accuracy_score(y_test, y_pred),
    "AUC": roc_auc_score(y_test, y_proba),
    "Precision": precision_score(y_test, y_pred),
    "Recall": recall_score(y_test, y_pred),
    "F1_Score": f1_score(y_test, y_pred),
    "MCC": matthews_corrcoef(y_test, y_pred)
}

# 4. Save
with open('Naive_Bayes.pkl', 'wb') as f:
    pickle.dump(nb_model, f)

all_results.append(nb_metrics)
print("--- Segment 4: Naive Bayes Complete ---")
print(pd.DataFrame([nb_metrics]))
# Out:
# --- Segment 4: Naive Bayes Complete ---
#          Model  Accuracy       AUC  Precision   Recall  F1_Score       MCC
# 0  Naive_Bayes  0.826519  0.800053    0.29932  0.44898  0.359184  0.270726

# %% [markdown]
# # 5: Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# 1. Initialize and Train
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# 2. Predict
y_pred = rf_model.predict(X_test)
y_proba = rf_model.predict_proba(X_test)[:, 1]

# 3. Calculate Metrics
rf_metrics = {
    "Model": "Random_Forest",
    "Accuracy": accuracy_score(y_test, y_pred),
    "AUC": roc_auc_score(y_test, y_proba),
    "Precision": precision_score(y_test, y_pred),
    "Recall": recall_score(y_test, y_pred),
    "F1_Score": f1_score(y_test, y_pred),
    "MCC": matthews_corrcoef(y_test, y_pred)
}

# 4. Save
with open('Random_Forest.pkl', 'wb') as f:
    pickle.dump(rf_model, f)

all_results.append(rf_metrics)
print("--- Segment 5: Random Forest Complete ---")
print(pd.DataFrame([rf_metrics]))
# Out:
# --- Segment 5: Random Forest Complete ---
#            Model  Accuracy       AUC  Precision   Recall  F1_Score       MCC
# 0  Random_Forest  0.901657  0.912216        0.6  0.27551  0.377622  0.361966

# %% [markdown]
# # 6: XGBoost Classifier

# %%
from xgboost import XGBClassifier

# 1. Initialize and Train
# use_label_encoder=False and eval_metric='logloss' prevent warnings in newer versions
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb_model.fit(X_train, y_train)

# 2. Predict
y_pred = xgb_model.predict(X_test)
y_proba = xgb_model.predict_proba(X_test)[:, 1]

# 3. Calculate Metrics
xgb_metrics = {
    "Model": "XGBoost",
    "Accuracy": accuracy_score(y_test, y_pred),
    "AUC": roc_auc_score(y_test, y_proba),
    "Precision": precision_score(y_test, y_pred),
    "Recall": recall_score(y_test, y_pred),
    "F1_Score": f1_score(y_test, y_pred),
    "MCC": matthews_corrcoef(y_test, y_pred)
}

# 4. Save
with open('XGBoost.pkl', 'wb') as f:
    pickle.dump(xgb_model, f)

all_results.append(xgb_metrics)
print("--- Segment 6: XGBoost Complete ---")
print(pd.DataFrame([xgb_metrics]))

# FINAL STEP: Save the consolidated results table
results_df = pd.DataFrame(all_results)
results_df.to_csv('model_comparison_final.csv', index=False)
print("\nFinal comparison table saved as 'model_comparison_final.csv'")
# Out:
# --- Segment 6: XGBoost Complete ---
#      Model  Accuracy       AUC  Precision    Recall  F1_Score       MCC
# 0  XGBoost  0.897238  0.905192   0.535211  0.387755  0.449704  0.400863
#
# Final comparison table saved as 'model_comparison_final.csv'
# c:\Users\e40052741\AppData\Local\anaconda3\envs\cudaV1_1\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:58:07] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
